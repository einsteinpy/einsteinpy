# %% [markdown]
# # Visualizing Precession in Schwarzschild Spacetime
#
# ### Importing required modules

# %%
import numpy as np
from plotly.offline import init_notebook_mode

# from einsteinpy.coordinates.utils import four_position, stacked_vec
from einsteinpy.coordinates import SphericalDifferential
from einsteinpy.geodesic import Geodesic
from einsteinpy.metric import Schwarzschild
from einsteinpy.plotting import GeodesicPlotter

# Essential when using Jupyter Notebook (May skip in Jupyter Lab)
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Defining Schwarzschild Metric and Initial Conditions

# %%
# Mass of the black hole in SI
M = 6e24

# Defining the initial coordinates of the test particle
# in SI
sph = SphericalDifferential(
    t=10000.0,
    r=130.0,
    theta=np.pi / 2,
    phi=-np.pi / 8,
    v_r=0.0,
    v_th=0.0,
    v_p=1900.0,
)

# Schwarzschild Metric Object
ms = Schwarzschild(M=M)

# Getting the initial state of the test particle
state = sph.state(metric=ms, time_like=True)

# %% [markdown]
# ### Calculating Geodesic

# %%
# Calculating Geodesic
geod = Geodesic(metric=ms, state=state, end_lambda=0.002, step_size=5e-8)
geod
# Out:
# Geodesic Object:
#
# Metric = ((
# Name: (Schwarzschild Metric),
# Coordinates: (S),
# Mass: (6e+24),
# Spin parameter: (0),
# Charge: (0),
# Schwarzschild Radius: (0.008911392322942397)
# )),
#
# Initial State = ([ 2.99792458e+12  1.30000000e+02  1.57079633e+00 -3.92699082e-01
#   1.00003462e+00  0.00000000e+00  0.00000000e+00  1.90000000e+03]),
#
# Trajectory = ([[ 2.99792458e+12  1.20104339e+02 -4.97488462e+01 ...  9.45228078e+04
#    2.28198245e+05  0.00000000e+00]
#  [ 2.99792458e+12  1.20108103e+02 -4.97397110e+01 ...  9.36471118e+04
#    2.28560931e+05 -5.80379473e-14]
#  [ 2.99792458e+12  1.20143810e+02 -4.96475618e+01 ...  8.48885265e+04
#    2.32184177e+05 -6.38424865e-13]
#  ...
#  [ 2.99792458e+12  1.29695466e+02 -6.52793459e-01 ...  1.20900076e+05
#    2.46971585e+05 -1.86135457e-10]
#  [ 2.99792458e+12  1.29741922e+02 -5.53995726e-01 ...  1.11380963e+05
#    2.47015864e+05 -1.74024168e-10]
#  [ 2.99792458e+12  1.29784572e+02 -4.55181739e-01 ...  1.01868292e+05
#    2.47052855e+05 -1.61922169e-10]])

# %% [markdown]
# ### Plotting the geodesic

# %%
obj = GeodesicPlotter()
obj.plot(geod)
obj.show()
# Out:
# <div>
#
#
#             <div id="e14018f9-11a3-4476-bd91-13ab440f4eda" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e14018f9-11a3-4476-bd91-13ab440f4eda")) {
#                     Plotly.newPlot(
#                         'e14018f9-11a3-4476-bd91-13ab440f4eda',
#                         [{"marker": {"color": "#ffcc00", "size": 0}, "mode": "markers", "name": "attractor", "type": "scatter", "x": [0], "y": [0]}, {"marker": {"color": "#c29c22", "line": {"width": 2}, "size": 5}, "mode": "lines", "name": "geodesic", "type": "scatter", "x": [120.10433922646727, 120.10810262495168, 120.14380985441778, 120.17601300585854, 120.20471065901762, 120.2299011947254, 120.25158279448635, 120.2697534400039, 120.28441091264266, 120.29555279282742, 120.30317645937885, 120.30727908878475, 120.30785765440747, 120.30490892562558, 120.29842946691025, 120.2884156368352, 120.27486358701941, 120.2577692610022, 120.23712839304947, 120.21293650689043, 120.18518891438372, 120.1538807141122, 120.11900678990499, 120.08056180928587, 120.03854022184689, 119.99293625754568, 119.94374392492558, 119.89095700925664, 119.83456907059653, 119.77457344176968, 119.71096322626289, 119.64373129603601, 119.57287028924567, 119.49837260788038, 119.42023041530514, 119.33843563371327, 119.2529799414837, 119.16385477044129, 119.071051303018, 118.9745604693124, 118.87437294404523, 118.77047914340818, 118.66286922180322, 118.55153306846985, 118.43646030399691, 118.31764027671628, 118.19506205897495, 118.06871444328225, 117.93858593832861, 117.80466476487241, 117.6669388514908, 117.52539583019079, 117.38002303187635, 117.23080748166716, 117.07773589406453, 116.92079466795987, 116.7599698814805, 116.59524728666825, 116.42661230398477, 116.2540500166386, 116.07754516472782, 115.8970821391923, 115.71264497556923, 115.52421734754523, 115.33178256029818, 115.13532354362151, 114.9348228448233, 114.73026262139257, 114.521624633424, 114.30889023579304, 114.09204037007181, 113.87105555617681, 113.64591588373816, 113.41660100318026, 113.18309011650302, 112.94536196775215, 112.70339483316664, 112.45716651099126, 112.20665431094048, 111.95183504330072, 111.69268500765595, 111.42917998122206, 111.16129520677393, 110.88900538014853, 110.61228463730683, 110.33110654093588, 110.04544406657209, 109.75526958822519, 109.46055486348175, 109.16127101806559, 108.8573885298318, 108.54887721216912, 108.23570619678479, 107.91784391584409, 107.59525808343545, 107.26791567633063, 106.93578291400705, 106.59882523789875, 106.25700728983917, 105.91029288965784, 105.55864501189082, 105.20202576156147, 104.84039634898703, 104.47371706356276, 104.10194724647279, 103.72504526227429, 103.3429684692975, 102.95567318880121, 102.56311467281965, 102.16524707063203, 101.76202339378263, 101.35339547957383, 100.93931395295019, 100.51972818668592, 100.09458625978255, 99.66383491397728, 99.22741950825609, 98.78528397125815, 98.33737075145065, 97.8836207649445, 97.42397334081262, 96.95836616376235, 96.48673521400333, 96.0090147041404, 95.52513701290854, 95.03503261555389, 94.53863001064919, 94.03585564311706, 93.5266338232163, 93.01088664122766, 92.48853387755484, 91.95949290793388, 91.42367860341909, 90.88100322478651, 90.33137631096689, 89.77470456108627, 89.21089170965772, 88.63983839442758, 88.0614420163363, 87.47559659100631, 86.88219259111627, 86.28111677896281, 85.67225202844588, 85.05547713564243, 84.43066661705312, 83.79769049451845, 83.15641406570158, 82.50669765892548, 81.84839637102833, 81.1813597867639, 80.50543167811853, 79.82044968174273, 79.12624495250053, 78.42264179091809, 77.70945724206474, 76.986500663117, 76.25357325653574, 75.5104675654223, 74.75696692720356, 73.99284488132159, 73.2178645260589, 72.43177781900548, 71.63432481495356, 70.82523283417541, 70.00421555307504, 69.17097200808651, 68.32518550238687, 67.46652240346658, 66.59463081781065, 65.7091391268363, 64.8096543657424, 63.895760423969854, 62.96701604245137, 62.02295257861431, 61.06307150503611, 60.086841601533784, 59.093695793044134, 58.08302757659087, 57.05418696951732, 56.0064758974414, 54.93914292334665, 53.85137719791464, 52.74230148437515, 51.61096407711509, 50.45632938976406, 49.27726693233855, 48.07253832395596, 46.84078189156926, 45.580494277539884, 44.29000830731615, 42.96746613500757, 41.61 ...

# %% [markdown]
# Apsidal Precession is easily observed in the plot above.
