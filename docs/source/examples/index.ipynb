# %% [markdown]
# # Example Gallery
#
# ![logo_text.png](../_static/EinsteinPy_trans.png)
#
# Here you can browse a gallery of examples, using EinsteinPy, in the form of Jupyter notebooks.

# %% [markdown]
# ## [Animations in EinsteinPy!](./Animations%20in%20EinsteinPy.ipynb)
#
# [![precession_anim](../_static//anim.gif)](./Animations%20in%20EinsteinPy.ipynb)
#
#
# ## [Einstein Tensor calculations using Symbolic module](./Einstein%20Tensor%20symbolic%20calculation.ipynb)
#
# [![Einstein](./imgs/einstein.png)](./Einstein%20Tensor%20symbolic%20calculation.ipynb)
#
#
# ## [Lambdify in Symbolic module](./Lambdify%20symbolic%20calculation.ipynb)
#
# [![lambdifygenerated](./imgs/lambdifygenerated.png)](./Lambdify%20symbolic%20calculation.ipynb)
#
#
# ## [Playing with Contravariant and Covariant Indices in Tensors (Symbolic)](./Playing%20with%20Contravariant%20and%20Covariant%20Indices%20in%20Tensors%20(Symbolic).ipynb)
#
# [![contravariant_symbolic](./imgs/contravariant_symbolic.png)](./Playing%20with%20Contravariant%20and%20Covariant%20Indices%20in%20Tensors%20(Symbolic).ipynb)
#
#
# ## [Predefined Metrics in Symbolic Module](./Predefined%20Metrics%20in%20Symbolic%20Module.ipynb)
#
# [![predefined_metrics](./imgs/predefined_metrics.png)](./Predefined%20Metrics%20in%20Symbolic%20Module.ipynb)
#
#
# ## [Ricci Tensor and Scalar Curvature calculations using Symbolic module](./Ricci%20Tensor%20and%20Scalar%20Curvature%20symbolic%20calculation.ipynb)
#
# [![GregorioRicciCurbastro](./imgs/GregorioRicciCurbastro.jpg)](./Ricci%20Tensor%20and%20Scalar%20Curvature%20symbolic%20calculation.ipynb)
# <center><em>Gregorio Ricci-Curbastro</em></center>
#
#
# ## [Shadow cast by a thin emission disk around a Schwarzschild black hole](./Shadow%20cast%20by%20a%20thin%20emission%20disk%20around%20a%20Schwarzschild%20black%20hole.ipynb)
#
# [![shadow](./imgs/shadow.png)](./Shadow%20cast%20by%20a%20thin%20emission%20disk%20around%20a%20Schwarzschild%20black%20hole.ipynb)
#
#
# ## [Plotting Spatial Hypersurface Embedding for Schwarzschild Spacetime](./Plotting%20Spatial%20Hypersurface%20Embedding%20for%20Schwarzschild%20Spacetime.ipynb)
#
# [![hypersurface](./imgs/hypersurface_surface.png)](./Plotting%20Spatial%20Hypersurface%20Embedding%20for%20Schwarzschild%20Spacetime.ipynb)
#
#
# ## [Symbolically Understanding Christoffel Symbol and Riemann Metric Tensor using EinsteinPy](./Symbolically%20Understanding%20Christoffel%20Symbol%20and%20Riemann%20Curvature%20Tensor%20using%20EinsteinPy.ipynb)
#
# [![symbol](./imgs/symbol.png)](./Symbolically%20Understanding%20Christoffel%20Symbol%20and%20Riemann%20Curvature%20Tensor%20using%20EinsteinPy.ipynb)
#
#
# ## [Using Geodesics (Back-ends & Plotting).ipynb](./Using%20Geodesics%20(Back-ends%20%26%20Plotting).ipynb)
#
# [![spiral](./imgs/spiral.png)](./Using%20Geodesics%20(Back-ends%20%26%20Plotting).ipynb)
#
#
# ## [Visualizing Event Horizon and Ergosphere (Singularities) of Kerr Metric or Black Hole](./Visualizing%20Event%20Horizon%20and%20Ergosphere%20(Singularities)%20of%20Kerr%20Metric%20or%20Black%20Hole.ipynb)
#
# [![kerrblackhole](./imgs/kerrblackhole.png)](./Visualizing%20Event%20Horizon%20and%20Ergosphere%20(Singularities)%20of%20Kerr%20Metric%20or%20Black%20Hole.ipynb)
#
#
# ## [Visualizing Frame Dragging in Kerr Spacetime](./Visualizing%20Frame%20Dragging%20in%20Kerr%20Spacetime.ipynb)
#
# [![drag](./imgs/drag.png)](./Visualizing%20Frame%20Dragging%20in%20Kerr%20Spacetime.ipynb)
#
#
# ## [Visualizing Precession in Schwarzschild Spacetime](./Visualizing%20Precession%20in%20Schwarzschild%20Spacetime.ipynb)
#
# [![precession](./imgs/precession.png)](./Visualizing%20Precession%20in%20Schwarzschild%20Spacetime.ipynb)
#
#
# ## [Weyl Tensor calculations using Symbolic module](./Weyl%20Tensor%20symbolic%20calculation.ipynb)
#
# [![weyl](./imgs/HermannWeyl.jpeg)](./Weyl%20Tensor%20symbolic%20calculation.ipynb)
# <center><em>Hermann Weyl</em></center>
