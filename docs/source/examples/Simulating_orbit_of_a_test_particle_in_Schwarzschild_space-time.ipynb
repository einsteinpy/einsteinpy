# %% [markdown]
# # Simulating orbit of a test particle in Schwarzschild space-time
# ### Import the required modules

# %%
import numpy as np
import astropy.units as u
from einsteinpy.plotting import ScatterGeodesicPlotter
# Out:
# /Users/varunsingh/Documents/projects/einsteinpy/src/einsteinpy/utils/bl_coord_transforms.py:7: UserWarning: This module will be deprecated in EinsteinPy v0.3.0. Please switch to `einsteinpy.coordinates`.
#   "This module will be deprecated in EinsteinPy v0.3.0. Please switch to `einsteinpy.coordinates`."
# /Users/varunsingh/Documents/projects/einsteinpy/src/einsteinpy/utils/coord_transforms.py:7: UserWarning: This module will be deprecated in EinsteinPy v0.3.0. Please switch to `einsteinpy.coordinates`.
#   "This module will be deprecated in EinsteinPy v0.3.0. Please switch to `einsteinpy.coordinates`."

# %% [markdown]
# ### Defining various parameters
#   - Mass of the attractor (M)
#   - Initial position and velocity vectors of test partcle

# %%
M = 6e24 * u.kg
pos = [130*u.m, np.pi/2*u.rad, -np.pi/8*u.rad]
vel = [0*u.m/u.s, 0*u.rad/u.s, 1900*u.rad/u.s]

# %% [markdown]
# ### Plotting the animation

# %%
# %matplotlib notebook
obj = ScatterGeodesicPlotter(M)
obj.animate(pos, vel, 0.002, 5e-8, interval=25)
obj.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
